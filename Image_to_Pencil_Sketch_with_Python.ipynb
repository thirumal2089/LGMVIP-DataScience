# %% [markdown]
# <a href="https://colab.research.google.com/github/thirumal2089/LGMVIP-DataScience/blob/main/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LGMVIP-DATA SCIENCE INTERNSHIP**

# %% [markdown]
# Task 3 : Image to Pencil Sketch with Python

# %% [markdown]
# Dataset Link : https://i.pinimg.com/originals/93/98/75/9398754385c6708cb744a17644741456.jpg

# %% [markdown]
# **Importing Libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow as cvm
import matplotlib.pyplot as plt
from skimage import io
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
link="https://i.pinimg.com/originals/93/98/75/9398754385c6708cb744a17644741456.jpg"

# %% [markdown]
# **Loading an image of Swami Vivekananda**

# %%
image=io.imread(link)

# %%
image
# Out:
# array([[[ 97,  31,  15],
#         [ 97,  31,  15],
#         [ 97,  31,  15],
#         ...,
#         [233, 137,  97],
#         [228, 137, 119],
#         [ 80,   0,   0]],
#
#        [[ 97,  31,  15],
#         [ 97,  31,  15],
#         [ 97,  31,  15],
#         ...,
#         [233, 137,  97],
#         [228, 137, 119],
#         [ 80,   0,   0]],
#
#        [[ 97,  31,  15],
#         [ 97,  31,  15],
#         [ 96,  30,  14],
#         ...,
#         [233, 137,  97],
#         [228, 137, 119],
#         [ 80,   0,   0]],
#
#        ...,
#
#        [[ 30,   9,   8],
#         [ 30,   9,   8],
#         [ 30,   9,   8],
#         ...,
#         [ 72,  40,  41],
#         [ 60,  28,  29],
#         [ 44,  12,  13]],
#
#        [[ 27,   6,   5],
#         [ 27,   6,   5],
#         [ 27,   6,   5],
#         ...,
#         [ 62,  30,  31],
#         [ 53,  21,  22],
#         [ 39,   7,   8]],
#
#        [[ 23,   2,   1],
#         [ 23,   2,   1],
#         [ 23,   2,   1],
# ...

# %%
cvm(image)
# Out:
# <PIL.Image.Image image mode=RGB size=900x900 at 0x7FDCBDA28C10>

# %% [markdown]
# **Reducing the size of the image**

# %%
image = cv2.resize(image,(500,450))
cvm(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x450 at 0x7FDCBDA4AD50>

# %% [markdown]
# **Converting into Gray Scale**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 34,  34,  34, ..., 132, 136,  62],
#        [ 34,  33,  33, ..., 132, 136,  62],
#        [ 32,  32,  32, ..., 132, 136,  62],
#        ...,
#        [  8,   8,   8, ...,  28,  36,  18],
#        [ 11,  11,  11, ...,  39,  42,  20],
#        [  6,   6,   6, ...,  22,  26,  12]], dtype=uint8)

# %%
cvm(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FDCBE1AA490>

# %% [markdown]
# **Inverting the image**

# %%
inverted_image = cv2.bitwise_not(gray_image)
inverted_image
# Out:
# array([[221, 221, 221, ..., 123, 119, 193],
#        [221, 222, 222, ..., 123, 119, 193],
#        [223, 223, 223, ..., 123, 119, 193],
#        ...,
#        [247, 247, 247, ..., 227, 219, 237],
#        [244, 244, 244, ..., 216, 213, 235],
#        [249, 249, 249, ..., 233, 229, 243]], dtype=uint8)

# %%
cvm(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FDCBC9D1090>

# %% [markdown]
# **Smoothing the image**

# %%
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21), sigmaX=0, sigmaY=0)
image_smoothing
# Out:
# array([[223, 223, 223, ..., 129, 130, 130],
#        [223, 223, 223, ..., 129, 130, 131],
#        [223, 223, 223, ..., 129, 130, 131],
#        ...,
#        [247, 247, 247, ..., 222, 222, 223],
#        [247, 247, 246, ..., 221, 222, 222],
#        [247, 247, 246, ..., 221, 222, 222]], dtype=uint8)

# %%
cvm(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FDCBC9D1BD0>

# %% [markdown]
# **Pencil Sketch of the image**

# %%
def pencil_sketch(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
pencil_sketch = pencil_sketch(gray_image, image_smoothing)
cvm(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=500x450 at 0x7FDCBDA4A8D0>

# %% [markdown]
# **Conclusion** : Thus we can convert the image into pencil sketch using Python.
